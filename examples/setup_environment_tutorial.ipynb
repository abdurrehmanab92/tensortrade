# %% [markdown]
# ## Setup Data Fetching

# %%
# !pip install tensortrade
# !pip install ta
# Out:
# Requirement already satisfied: tensortrade in /usr/local/lib/python3.11/dist-packages (1.0.3)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from tensortrade) (1.26.4)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from tensortrade) (2.2.2)
# Requirement already satisfied: gym>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from tensortrade) (0.25.2)
# Requirement already satisfied: pyyaml>=5.1.2 in /usr/local/lib/python3.11/dist-packages (from tensortrade) (6.0.2)
# Requirement already satisfied: stochastic>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from tensortrade) (0.6.0)
# Requirement already satisfied: tensorflow>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from tensortrade) (2.18.0)
# Requirement already satisfied: ipython>=7.12.0 in /usr/local/lib/python3.11/dist-packages (from tensortrade) (7.34.0)
# Requirement already satisfied: matplotlib>=3.1.1 in /usr/local/lib/python3.11/dist-packages (from tensortrade) (3.10.0)
# Requirement already satisfied: plotly>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from tensortrade) (5.24.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym>=0.14.0->tensortrade) (3.1.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym>=0.14.0->tensortrade) (0.1.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.12.0->tensortrade) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.12.0->tensortrade) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=7.12.0->tensortrade) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=7.12.0->tensortrade) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.12.0->tensortrade) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.12.0->tensortrade) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=7.12.0->tensortrade) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=7.12.0->tensortrade) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=7.12.0->tensortrade) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.12.0->tensortrade) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->tensortrade) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->tensortrade) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->tensortrade) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->tensortrade) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->tensortrade) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->tensortrade) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->tensortrade) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->tensortrade) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.25.0->tensortrade) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.25.0->tensortrade) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=4.5.0->tensortrade) (8.5.0)
# Requirement already satisfied: scipy<2.0,>=1.3 in /usr/local/lib/python3.11/dist-packages (from stochastic>=0.6.0->tensortrade) (1.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1.0->tensortrade) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1.0->tensortrade) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1.0->tensortrade) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1.0->tensortrade) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1.0->tensortrade) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1.0->tensortrade) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1.0->tensortrade) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1.0->tensortrade) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1.0->tensortrade) (2.32.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1.0->tensortrade) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1.0->tensortrade) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1.0->tensortrade) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1.0->tensortrade) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1.0->tensortrade) (1.74.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1.0->tensortrade) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1.0->tensortrade) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1.0->tensortrade) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1.0->tensortrade) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.1.0->tensortrade) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow>=2.1.0->tensortrade) (0.45.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=7.12.0->tensortrade) (0.8.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.1.0->tensortrade) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.1.0->tensortrade) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.1.0->tensortrade) (0.17.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=7.12.0->tensortrade) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.12.0->tensortrade) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.1.0->tensortrade) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.1.0->tensortrade) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.1.0->tensortrade) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.1.0->tensortrade) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.1.0->tensortrade) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.1.0->tensortrade) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.1.0->tensortrade) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow>=2.1.0->tensortrade) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.1.0->tensortrade) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow>=2.1.0->tensortrade) (0.1.2)
# Collecting ta
#   Downloading ta-0.11.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from ta) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from ta) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->ta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->ta) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->ta) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->ta) (1.17.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29412 sha256=6457013b27df64389be33c40fd97d1305eb42f2b6811463a1cdf2c2af78caa1a
#   Stored in directory: /root/.cache/pip/wheels/a1/d7/29/7781cc5eb9a3659d032d7d15bdd0f49d07d2b24fec29f44bc4
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.11.0

# %%
import ta

import pandas as pd
import tensortrade.env.default as default

from tensortrade.data.cdd import CryptoDataDownload
from tensortrade.feed.core import Stream, DataFeed, NameSpace
from tensortrade.oms.instruments import USD, BTC, ETH, LTC
from tensortrade.oms.wallets import Wallet, Portfolio
from tensortrade.oms.exchanges import Exchange
from tensortrade.oms.services.execution.simulated import execute_order
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %% [markdown]
# ## Fetch Historical Data

# %%
cdd = CryptoDataDownload()

bitfinex_data = pd.concat([
    cdd.fetch("Bitfinex", "USD", "BTC", "1h").add_prefix("BTC:"),
    cdd.fetch("Bitfinex", "USD", "ETH", "1h").add_prefix("ETH:")
], axis=1)

bitstamp_data = pd.concat([
    cdd.fetch("Bitstamp", "USD", "BTC", "1h").add_prefix("BTC:"),
    cdd.fetch("Bitstamp", "USD", "LTC", "1h").add_prefix("LTC:")
], axis=1)

# %%
bitfinex_data.head()
# Out:
#              BTC:date      BTC:unix  BTC:open  BTC:high  BTC:low  BTC:close  \
# 0 2018-05-15 06:00:00  1.526364e+09    8723.8    8793.0   8714.9     8739.0
# 1 2018-05-15 07:00:00  1.526368e+09    8739.0    8754.8   8719.3     8743.0
# 2 2018-05-15 08:00:00  1.526371e+09    8743.0    8743.1   8653.2     8723.7
# 3 2018-05-15 09:00:00  1.526375e+09    8723.7    8737.8   8701.2     8708.1
# 4 2018-05-15 10:00:00  1.526378e+09    8708.1    8855.7   8695.8     8784.4
#
#     BTC:volume            ETH:date    ETH:unix  ETH:open  ETH:high  ETH:low  \
# 0   8988053.53 2018-05-15 06:00:00  1526364000    733.12    736.48   731.19
# 1   2288904.12 2018-05-15 07:00:00  1526367600    733.04    735.99   731.70
# 2   8891773.14 2018-05-15 08:00:00  1526371200    734.64    734.65   722.00
# 3   2054868.28 2018-05-15 09:00:00  1526374800    731.32    732.00   728.44
# 4  17309722.58 2018-05-15 10:00:00  1526378400    728.44    739.30   725.52
#
#    ETH:close  ETH:volume
# 0     733.04  4246576.84
# 1     734.64  2044880.32
# 2     731.32  7891317.14
# 3     728.44  2111099.12
# 4     735.21  7197617.75

# %%
bitstamp_data.head()
# Out:
#              BTC:date      BTC:unix  BTC:open  BTC:high  BTC:low  BTC:close  \
# 0 2018-05-15 06:00:00  1.526364e+09   8733.86   8796.68  8707.28    8740.99
# 1 2018-05-15 07:00:00  1.526368e+09   8740.99   8766.00  8721.11    8739.00
# 2 2018-05-15 08:00:00  1.526371e+09   8739.00   8750.27  8660.53    8728.49
# 3 2018-05-15 09:00:00  1.526375e+09   8728.49   8754.40  8701.35    8708.32
# 4 2018-05-15 10:00:00  1.526378e+09   8708.32   8865.00  8695.11    8795.90
#
#    BTC:volume            LTC:date    LTC:unix  LTC:open  LTC:high  LTC:low  \
# 0      559.93 2018-05-15 06:00:00  1526364000    147.20    148.70   147.01
# 1      273.58 2018-05-15 07:00:00  1526367600    147.20    148.02   146.80
# 2      917.79 2018-05-15 08:00:00  1526371200    147.50    147.50   144.54
# 3      182.62 2018-05-15 09:00:00  1526374800    145.64    146.62   145.15
# 4     1260.69 2018-05-15 10:00:00  1526378400    145.54    149.14   144.95
#
#    LTC:close  LTC:volume
# 0     147.20     1907.28
# 1     147.50      557.94
# 2     145.64     3606.38
# 3     145.54      369.67
# 4     147.66     2755.48

# %% [markdown]
# ## Define Exchanges
#
# An exchange needs a name, an execution service, and streams of price data in order to function properly.
#
# The setups supported right now are the simulated execution service using simulated or stochastic data. More execution services will be made available in the future, as well as price streams so that live data and execution can be supported.

# %%
bitfinex = Exchange("bitfinex", service=execute_order)(
    Stream.source(list(bitfinex_data['BTC:close']), dtype="float").rename("USD-BTC"),
    Stream.source(list(bitfinex_data['ETH:close']), dtype="float").rename("USD-ETH")
)

bitstamp = Exchange("bitstamp", service=execute_order)(
    Stream.source(list(bitstamp_data['BTC:close']), dtype="float").rename("USD-BTC"),
    Stream.source(list(bitstamp_data['LTC:close']), dtype="float").rename("USD-LTC")
)

# %% [markdown]
# Now that the exchanges have been defined we can define our features that we would like to include, excluding the prices we have provided for the exchanges.

# %% [markdown]
# ## Define External Data Feed
#
# Here we will define the feed to use whatever data you would like. From financial indicators to alternative datasets, they will all have to be defined and incorporated into the `DataFeed` provided to the environment.

# %%
# Add all features for bitstamp BTC & ETH
bitfinex_btc = bitfinex_data.loc[:, [name.startswith("BTC") for name in bitfinex_data.columns]]
bitfinex_eth = bitfinex_data.loc[:, [name.startswith("ETH") for name in bitfinex_data.columns]]

ta.add_all_ta_features(
    bitfinex_btc,
    colprefix="BTC:",
    **{k: "BTC:" + k for k in ['open', 'high', 'low', 'close', 'volume']}
)


with NameSpace("bitfinex"):
    bitfinex_streams = [
        Stream.source(list(bitfinex_btc[c]), dtype="float").rename(c) for c in bitfinex_btc.columns
    ]
    bitfinex_streams += [
        Stream.source(list(bitfinex_eth[c]), dtype="float").rename(c) for c in bitfinex_eth.columns
    ]


# Add all features for bitstamp BTC & LTC
bitstamp_btc = bitstamp_data.loc[:, [name.startswith("BTC") for name in bitstamp_data.columns]]
bitstamp_ltc = bitstamp_data.loc[:, [name.startswith("LTC") for name in bitstamp_data.columns]]

ta.add_all_ta_features(
    bitstamp_ltc,
    colprefix="LTC:",
    **{k: "LTC:" + k for k in ['open', 'high', 'low', 'close', 'volume']}
)

with NameSpace("bitstamp"):
    bitstamp_streams = [
        Stream.source(list(bitstamp_btc[c]), dtype="float").rename(c) for c in bitstamp_btc.columns
    ]
    bitstamp_streams += [
        Stream.source(list(bitstamp_ltc[c]), dtype="float").rename(c) for c in bitstamp_ltc.columns
    ]


feed = DataFeed(bitfinex_streams + bitstamp_streams)
# Out:
# /usr/local/lib/python3.11/dist-packages/ta/wrapper.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_adi"] = AccDistIndexIndicator(
# /usr/local/lib/python3.11/dist-packages/ta/wrapper.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_obv"] = OnBalanceVolumeIndicator(
# /usr/local/lib/python3.11/dist-packages/ta/wrapper.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_cmf"] = ChaikinMoneyFlowIndicator(
# /usr/local/lib/python3.11/dist-packages/ta/wrapper.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_fi"] = ForceIndexIndicator(
# /usr/local/lib/python3.11/dist-packages/ta/wrapper.py:114: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_em"] = indicator_eom.ease_of_movement()
# /usr/local/lib/python3.11/dist-packages/ta/wrapper.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_sma_em"] = indicator_eom.sma_ease_of_movement()
# /usr/local/lib/python3.11/dist-packages/ta/volume.py:290: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   self._vpt = (self._close.pct_change() * self._volume).cumsum()
# /usr/local/lib/python3.11/dist-packages/ta/volume.py:327: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   price_change = self._close.pct_change()
# /usr/local/lib/python3.11/dist-packages/ta/wrapper.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_adi"] = AccDistIndexIndicator(
# /usr/local/lib/python3.11/dist-packages/ta/wrapper.py:96: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_obv"] = OnBalanceVolumeIndicator(
# /usr/local/lib/python3.11/dist-packages/ta/wrapper.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_cmf"] = ChaikinMoneyFlowIndicator(
# /usr/local/lib/python3.11/dist-packages/ta/wrapper.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_fi"] = ForceIndexIndicator(
# /usr/local/lib/python3.11/dist-packages/ta/wrapper.py:114: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_em"] = indicator_eom.ease_of_movement()
# /usr/local/lib/python3.11/dist-packages/ta/wrapper.py:115: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"{colprefix}volume_sma_em"] = indicator_eom.sma_ease_of_movement()

# %%
feed.next()
# Out:
# {'bitfinex:/BTC:date': Timestamp('2018-05-15 06:00:00'),
#  'bitfinex:/BTC:unix': 1526364000.0,
#  'bitfinex:/BTC:open': 8723.8,
#  'bitfinex:/BTC:high': 8793.0,
#  'bitfinex:/BTC:low': 8714.9,
#  'bitfinex:/BTC:close': 8739.0,
#  'bitfinex:/BTC:volume': 8988053.53,
#  'bitfinex:/BTC:volume_adi': -3441008.969871901,
#  'bitfinex:/BTC:volume_obv': 8988053.53,
#  'bitfinex:/BTC:volume_cmf': nan,
#  'bitfinex:/BTC:volume_fi': nan,
#  'bitfinex:/BTC:volume_em': nan,
#  'bitfinex:/BTC:volume_sma_em': nan,
#  'bitfinex:/BTC:volume_vpt': nan,
#  'bitfinex:/BTC:volume_vwap': nan,
#  'bitfinex:/BTC:volume_mfi': nan,
#  'bitfinex:/BTC:volume_nvi': 1000.0,
#  'bitfinex:/BTC:volatility_bbm': nan,
#  'bitfinex:/BTC:volatility_bbh': nan,
#  'bitfinex:/BTC:volatility_bbl': nan,
#  'bitfinex:/BTC:volatility_bbw': nan,
#  'bitfinex:/BTC:volatility_bbp': nan,
#  'bitfinex:/BTC:volatility_bbhi': 0.0,
#  'bitfinex:/BTC:volatility_bbli': 0.0,
#  'bitfinex:/BTC:volatility_kcc': nan,
#  'bitfinex:/BTC:volatility_kch': 8827.066666666668,
#  'bitfinex:/BTC:volatility_kcl': 8670.866666666667,
#  'bitfinex:/BTC:volatility_kcw': nan,
#  'bitfinex:/BTC:volatility_kcp': 0.4361929150661517,
#  'bitfinex:/BTC:volatility_kchi': 0.0,
#  'bitfinex:/BTC:volatility_kcli': 0.0,
#  'bitfinex:/BTC:volatility_dcl': nan,
#  'bitfinex:/BTC:volatility_dch': nan,
#  'bitfinex:/BTC:volatility_dcm': nan,
#  'bitfinex:/BTC:volatility_dcw': nan,
#  'bitfinex:/BTC:volatility_dcp': nan,
#  'bitfinex:/BTC:volatility_atr': 0.0,
#  'bitfinex:/BTC:volatility_ui': nan,
#  'bitfinex:/BTC:trend_macd': nan,
#  'bitfinex:/BTC:trend_macd_signal': nan,
#  'bitfinex:/BTC:trend_macd_diff': nan,
#  'bitfinex:/BTC:trend_sma_fast': nan,
#  'bitfinex:/BTC:trend_sma_slow': nan,
#  'bitfinex:/BTC:trend_ema_fast': nan,
#  'bitfinex:/BTC:trend_ema_slow': nan,
#  'bitfinex:/BTC:trend_vortex_ind_pos': nan,
#  'bitfinex:/BTC:trend_vortex_ind_neg': nan,
#  'bitfinex:/BTC:trend_vortex_ind_diff': nan,
#  'bitfinex:/BTC:trend_trix': nan,
#  'bitfinex:/BTC:trend_mass_index': nan,
#  'bitfinex:/BTC:trend_dpo': nan,
#  'bitfinex:/BTC:trend_kst': nan,
#  'bitfinex:/BTC:trend_kst_sig': nan,
#  'bitfinex:/BTC:trend_kst_diff': nan,
#  'bitfinex:/BTC:trend_ichimoku_conv': nan,
#  'bitfinex:/BTC:trend_ichimoku_base': nan,
#  'bitfinex:/BTC:trend_ichimoku_a': nan,
#  'bitfinex:/BTC:trend_ichimoku_b': 8753.95,
#  'bitfinex:/BTC:trend_stc': nan,
#  'bitfinex:/BTC:trend_adx': 0.0,
#  'bitfinex:/BTC:trend_adx_pos': 0.0,
#  'bitfinex:/BTC:trend_adx_neg': 0.0,
#  'bitfinex:/BTC:trend_cci': nan,
#  'bitfinex:/BTC:trend_visual_ichimoku_a': 34606.16124033415,
#  'bitfinex:/BTC:trend_visual_ichimoku_b': 34559.24305545331,
#  'bitfinex:/BTC:trend_aroon_up': nan,
#  'bitfinex:/BTC:trend_aroon_down': nan,
#  'bitfinex:/BTC:trend_aroon_ind': nan,
#  'bitfinex:/BTC:trend_psar_up': nan,
#  'bitfinex:/BTC:trend_psar_down': nan,
#  'bitfinex:/BTC:trend_psar_up_indicator': 0.0,
#  'bitfinex:/BTC:trend_psar_down_indicator': 0.0,
#  'bitfinex:/BTC:momentum_rsi': nan,
#  'bitfinex:/BTC:momentum_stoch_rsi': nan,
#  'bitfinex:/BTC:momentum_stoch_rsi_k': nan,
#  'bitfinex:/BTC:momentum_stoch_rsi_d': nan,
#  'bitfinex:/BTC:momentum_tsi': nan,
#  'bitfinex:/BTC:momentum_uo': nan,
#  'bitfinex:/BTC:momentum_stoch': nan,
#  'bitfinex:/BTC:momentum_stoch_signal': nan,
#  'bitfinex:/BTC:momentum_wr': nan,
#  'bitfinex:/BTC:momentum_ao': nan,
#  'bitfinex:/BTC:momentum_roc': nan,
#  'bitfinex:/BTC:momentum_ppo': nan,
#  'bitfinex:/BTC:momentum_ppo_signal': nan,
#  'bitfinex:/BTC:momentum_ppo_hist': nan,
#  'bitfinex:/BTC:momentum_pvo': nan,
#  'bitfinex:/BTC:momentum_pvo_signal': nan,
#  'bitfinex:/BTC:momentum_pvo_hist': nan,
#  'bitfinex:/BTC:momentum_kama': nan,
#  'bitfinex:/BTC:others_dr': nan,
#  'bitfinex:/BTC:others_dlr': nan,
#  'bitfinex:/BTC:others_cr': 0.0,
#  'bitfinex:/ETH:date': Timestamp('2018-05-15 06:00:00'),
#  'bitfinex:/ETH:unix': 1526364000,
#  'bitfinex:/ETH:open': 733.12,
#  'bitfinex:/ETH:high': 736.48,
#  'bitfinex:/ETH:low': 731.19,
#  'bitfinex:/ETH:close': 733.04,
#  'bitfinex:/ETH:volume': 4246576.84,
#  'bitstamp:/BTC:date': Timestamp('2018-05-15 06:00:00'),
#  'bitstamp:/BTC:unix': 1526364000.0,
#  'bitstamp:/BTC:open': 8733.86,
#  'bitstamp:/BTC:high': 8796.68,
#  'bitstamp:/BTC:low': 8707.28,
#  'bitstamp:/BTC:close': 8740.99,
#  'bitstamp:/BTC:volume': 559.93,
#  'bitstamp:/LTC:date': Timestamp('2018-05-15 06:00:00'),
#  'bitstamp:/LTC:unix': 1526364000,
#  'bitstamp:/LTC:open': 147.2,
#  'bitstamp:/LTC:high': 148.7,
#  'bitstamp:/LTC:low': 147.01,
#  'bitstamp:/LTC:close': 147.2,
#  'bitstamp:/LTC:volume': 1907.28,
#  'bitstamp:/LTC:volume_adi': -1478.424142011839,
#  'bitstamp:/LTC:volume_obv': 1907.28,
#  'bitstamp:/LTC:volume_cmf': nan,
#  'bitstamp:/LTC:volume_fi': nan,
#  'bitstamp:/LTC:volume_em': nan,
#  'bitstamp:/LTC:volume_sma_em': nan,
#  'bitstamp:/LTC:volume_vpt': nan,
#  'bitstamp:/LTC:volume_vwap': nan,
#  'bitstamp:/LTC:volume_mfi': nan,
#  'bitstamp:/LTC:volume_nvi': 1000.0,
#  'bitstamp:/LTC:volatility_bbm': nan,
#  'bitstamp:/LTC:volatility_bbh': nan,
#  'bitstamp:/LTC:volatility_bbl': nan,
#  'bitstamp:/LTC:volatility_bbw': nan,
#  'bitstamp:/LTC:volatility_bbp': nan,
#  'bitstamp:/LTC:volatility_bbhi': 0.0,
#  'bitstamp:/LTC:volatility_bbli': 0.0,
#  'bitstamp:/LTC:volatility_kcc': nan,
#  'bitstamp:/LTC:volatility_kch': 149.32666666666665,
#  'bitstamp:/LTC:volatility_kcl': 145.94666666666666,
#  'bitstamp:/LTC:volatility_kcw': nan,
#  'bitstamp:/LTC:volatility_kcp': 0.3708086785009858,
#  'bitstamp:/LTC:volatility_kchi': 0.0,
#  'bitstamp:/LTC:volatility_kcli': 0.0,
#  'bitstamp:/LTC:volatility_dcl': nan,
#  'bitstamp:/LTC:volatility_dch': nan,
#  'bitstamp:/LTC:volatility_dcm': nan,
#  'bitstamp:/LTC:volatility_dcw': nan,
#  'bitstamp:/LTC:volatility_dcp': nan,
#  'bitstamp:/LTC:volatility_atr': 0.0,
#  'bitstamp:/LTC:volatility_ui': nan,
#  'bitstamp:/LTC:trend_macd': nan,
#  'bitstamp:/LTC:trend_macd_signal': nan,
#  'bitstamp:/LTC:trend_macd_diff': nan,
#  'bitstamp:/LTC:trend_sma_fast': nan,
#  'bitstamp:/LTC:trend_sma_slow': nan,
#  'bitstamp:/LTC:trend_ema_fast': nan,
#  'bitstamp:/LTC:trend_ema_slow': nan,
#  'bitstamp:/LTC:trend_vortex_ind_pos': nan,
#  'bitstamp:/LTC:trend_vortex_ind_neg': nan,
#  'bitstamp:/LTC:trend_vortex_ind_diff': nan,
#  'bitstamp:/LTC:trend_trix': nan,
#  'bitstamp:/LTC:trend_mass_index': nan,
#  'bitstamp:/LTC:trend_dpo': nan,
#  'bitstamp:/LTC:trend_kst': nan,
#  'bitstamp:/LTC:trend_kst_sig': nan,
#  'bitstamp:/LTC:trend_kst_diff': nan,
#  'bitstamp:/LTC:trend_ichimoku_conv': nan,
#  'bitstamp:/LTC:trend_ichimoku_base': nan,
#  'bitstamp:/LTC:trend_ichimoku_a': nan,
#  'bitstamp:/LTC:trend_ichimoku_b': 147.855,
#  'bitstamp:/LTC:trend_stc': nan,
#  'bitstamp:/LTC:trend_adx': 0.0,
#  'bitstamp:/LTC:trend_adx_pos': 0.0,
#  'bitstamp:/LTC:trend_adx_neg': 0.0,
#  'bitstamp:/LTC:trend_cci': nan,
#  'bitstamp:/LTC:trend_visual_ichimoku_a': 89.93063732472385,
#  'bitstamp:/LTC:trend_visual_ichimoku_b': 89.92024916549335,
#  'bitstamp:/LTC:trend_aroon_up': nan,
#  'bitstamp:/LTC:trend_aroon_down': nan,
#  'bitstamp:/LTC:trend_aroon_ind': nan,
#  'bitstamp:/LTC:trend_psar_up': nan,
#  'bitstamp:/LTC:trend_psar_down': nan,
#  'bitstamp:/LTC:trend_psar_up_indicator': 0.0,
#  'bitstamp:/LTC:trend_psar_down_indicator': 0.0,
#  'bitstamp:/LTC:momentum_rsi': nan,
#  'bitstamp:/LTC:momentum_stoch_rsi': nan,
#  'bitstamp:/LTC:momentum_stoch_rsi_k': nan,
#  'bitstamp:/LTC:momentum_stoch_rsi_d': nan,
#  'bitstamp:/LTC:momentum_tsi': nan,
#  'bitstamp:/LTC:momentum_uo': nan,
#  'bitstamp:/LTC:momentum_stoch': nan,
#  'bitstamp:/LTC:momentum_stoch_signal': nan,
#  'bitstamp:/LTC:momentum_wr': nan,
#  'bitstamp:/LTC:momentum_ao': nan,
#  'bitstamp:/LTC:momentum_roc': nan,
#  'bitstamp:/LTC:momentum_ppo': nan,
#  'bitstamp:/LTC:momentum_ppo_signal': nan,
#  'bitstamp:/LTC:momentum_ppo_hist': nan,
#  'bitstamp:/LTC:momentum_pvo': nan,
#  'bitstamp:/LTC:momentum_pvo_signal': nan,
#  'bitstamp:/LTC:momentum_pvo_hist': nan,
#  'bitstamp:/LTC:momentum_kama': nan,
#  'bitstamp:/LTC:others_dr': nan,
#  'bitstamp:/LTC:others_dlr': nan,
#  'bitstamp:/LTC:others_cr': 0.0}

# %% [markdown]
# ## Portfolio
#
# Make the portfolio using the any combinations of exchanges and intruments that the exchange supports

# %%
portfolio = Portfolio(USD, [
    Wallet(bitfinex, 10000 * USD),
    Wallet(bitfinex, 10 * BTC),
    Wallet(bitfinex, 5 * ETH),
    Wallet(bitstamp, 1000 * USD),
    Wallet(bitstamp, 5 * BTC),
    Wallet(bitstamp, 3 * LTC),
])

# %% [markdown]
# ## Environment

# %%
env = default.create(
    portfolio=portfolio,
    action_scheme="managed-risk",
    reward_scheme="simple",
    feed=feed,
    window_size=15,
    enable_logger=False
)

# %%
env.observer.feed.next()
# Out:
# {'internal': {'bitfinex:/USD-BTC': 8739.0,
#   'bitfinex:/USD-ETH': 733.04,
#   'bitfinex:/USD:/free': 10000.0,
#   'bitfinex:/USD:/locked': 0.0,
#   'bitfinex:/USD:/total': 10000.0,
#   'bitfinex:/BTC:/free': 10.0,
#   'bitfinex:/BTC:/locked': 0.0,
#   'bitfinex:/BTC:/total': 10.0,
#   'bitfinex:/BTC:/worth': 87390.0,
#   'bitfinex:/ETH:/free': 5.0,
#   'bitfinex:/ETH:/locked': 0.0,
#   'bitfinex:/ETH:/total': 5.0,
#   'bitfinex:/ETH:/worth': 3665.2,
#   'bitstamp:/USD-BTC': 8740.99,
#   'bitstamp:/USD-LTC': 147.2,
#   'bitstamp:/USD:/free': 1000.0,
#   'bitstamp:/USD:/locked': 0.0,
#   'bitstamp:/USD:/total': 1000.0,
#   'bitstamp:/BTC:/free': 5.0,
#   'bitstamp:/BTC:/locked': 0.0,
#   'bitstamp:/BTC:/total': 5.0,
#   'bitstamp:/BTC:/worth': 43704.95,
#   'bitstamp:/LTC:/free': 3.0,
#   'bitstamp:/LTC:/locked': 0.0,
#   'bitstamp:/LTC:/total': 3.0,
#   'bitstamp:/LTC:/worth': 441.59999999999997,
#   'net_worth': 146201.75},
#  'external': {'bitfinex:/BTC:date': Timestamp('2018-05-15 06:00:00'),
#   'bitfinex:/BTC:unix': 1526364000.0,
#   'bitfinex:/BTC:open': 8723.8,
#   'bitfinex:/BTC:high': 8793.0,
#   'bitfinex:/BTC:low': 8714.9,
#   'bitfinex:/BTC:close': 8739.0,
#   'bitfinex:/BTC:volume': 8988053.53,
#   'bitfinex:/BTC:volume_adi': -3441008.969871901,
#   'bitfinex:/BTC:volume_obv': 8988053.53,
#   'bitfinex:/BTC:volume_cmf': nan,
#   'bitfinex:/BTC:volume_fi': nan,
#   'bitfinex:/BTC:volume_em': nan,
#   'bitfinex:/BTC:volume_sma_em': nan,
#   'bitfinex:/BTC:volume_vpt': nan,
#   'bitfinex:/BTC:volume_vwap': nan,
#   'bitfinex:/BTC:volume_mfi': nan,
#   'bitfinex:/BTC:volume_nvi': 1000.0,
#   'bitfinex:/BTC:volatility_bbm': nan,
#   'bitfinex:/BTC:volatility_bbh': nan,
#   'bitfinex:/BTC:volatility_bbl': nan,
#   'bitfinex:/BTC:volatility_bbw': nan,
#   'bitfinex:/BTC:volatility_bbp': nan,
#   'bitfinex:/BTC:volatility_bbhi': 0.0,
#   'bitfinex:/BTC:volatility_bbli': 0.0,
#   'bitfinex:/BTC:volatility_kcc': nan,
#   'bitfinex:/BTC:volatility_kch': 8827.066666666668,
#   'bitfinex:/BTC:volatility_kcl': 8670.866666666667,
#   'bitfinex:/BTC:volatility_kcw': nan,
#   'bitfinex:/BTC:volatility_kcp': 0.4361929150661517,
#   'bitfinex:/BTC:volatility_kchi': 0.0,
#   'bitfinex:/BTC:volatility_kcli': 0.0,
#   'bitfinex:/BTC:volatility_dcl': nan,
#   'bitfinex:/BTC:volatility_dch': nan,
#   'bitfinex:/BTC:volatility_dcm': nan,
#   'bitfinex:/BTC:volatility_dcw': nan,
#   'bitfinex:/BTC:volatility_dcp': nan,
#   'bitfinex:/BTC:volatility_atr': 0.0,
#   'bitfinex:/BTC:volatility_ui': nan,
#   'bitfinex:/BTC:trend_macd': nan,
#   'bitfinex:/BTC:trend_macd_signal': nan,
#   'bitfinex:/BTC:trend_macd_diff': nan,
#   'bitfinex:/BTC:trend_sma_fast': nan,
#   'bitfinex:/BTC:trend_sma_slow': nan,
#   'bitfinex:/BTC:trend_ema_fast': nan,
#   'bitfinex:/BTC:trend_ema_slow': nan,
#   'bitfinex:/BTC:trend_vortex_ind_pos': nan,
#   'bitfinex:/BTC:trend_vortex_ind_neg': nan,
#   'bitfinex:/BTC:trend_vortex_ind_diff': nan,
#   'bitfinex:/BTC:trend_trix': nan,
#   'bitfinex:/BTC:trend_mass_index': nan,
#   'bitfinex:/BTC:trend_dpo': nan,
#   'bitfinex:/BTC:trend_kst': nan,
#   'bitfinex:/BTC:trend_kst_sig': nan,
#   'bitfinex:/BTC:trend_kst_diff': nan,
#   'bitfinex:/BTC:trend_ichimoku_conv': nan,
#   'bitfinex:/BTC:trend_ichimoku_base': nan,
#   'bitfinex:/BTC:trend_ichimoku_a': nan,
#   'bitfinex:/BTC:trend_ichimoku_b': 8753.95,
#   'bitfinex:/BTC:trend_stc': nan,
#   'bitfinex:/BTC:trend_adx': 0.0,
#   'bitfinex:/BTC:trend_adx_pos': 0.0,
#   'bitfinex:/BTC:trend_adx_neg': 0.0,
#   'bitfinex:/BTC:trend_cci': nan,
#   'bitfinex:/BTC:trend_visual_ichimoku_a': 34606.16124033415,
#   'bitfinex:/BTC:trend_visual_ichimoku_b': 34559.24305545331,
#   'bitfinex:/BTC:trend_aroon_up': nan,
#   'bitfinex:/BTC:trend_aroon_down': nan,
#   'bitfinex:/BTC:trend_aroon_ind': nan,
#   'bitfinex:/BTC:trend_psar_up': nan,
#   'bitfinex:/BTC:trend_psar_down': nan,
#   'bitfinex:/BTC:trend_psar_up_indicator': 0.0,
#   'bitfinex:/BTC:trend_psar_down_indicator': 0.0,
#   'bitfinex:/BTC:momentum_rsi': nan,
#   'bitfinex:/BTC:momentum_stoch_rsi': nan,
#   'bitfinex:/BTC:momentum_stoch_rsi_k': nan,
#   'bitfinex:/BTC:momentum_stoch_rsi_d': nan,
#   'bitfinex:/BTC:momentum_tsi': nan,
#   'bitfinex:/BTC:momentum_uo': nan,
#   'bitfinex:/BTC:momentum_stoch': nan,
#   'bitfinex:/BTC:momentum_stoch_signal': nan,
#   'bitfinex:/BTC:momentum_wr': nan,
#   'bitfinex:/BTC:momentum_ao': nan,
#   'bitfinex:/BTC:momentum_roc': nan,
#   'bitfinex:/BTC:momentum_ppo': nan,
#   'bitfinex:/BTC:momentum_ppo_signal': nan,
#   'bitfinex:/BTC:momentum_ppo_hist': nan,
#   'bitfinex:/BTC:momentum_pvo': nan,
#   'bitfinex:/BTC:momentum_pvo_signal': nan,
#   'bitfinex:/BTC:momentum_pvo_hist': nan,
#   'bitfinex:/BTC:momentum_kama': nan,
#   'bitfinex:/BTC:others_dr': nan,
#   'bitfinex:/BTC:others_dlr': nan,
#   'bitfinex:/BTC:others_cr': 0.0,
#   'bitfinex:/ETH:date': Timestamp('2018-05-15 06:00:00'),
#   'bitfinex:/ETH:unix': 1526364000,
#   'bitfinex:/ETH:open': 733.12,
#   'bitfinex:/ETH:high': 736.48,
#   'bitfinex:/ETH:low': 731.19,
#   'bitfinex:/ETH:close': 733.04,
#   'bitfinex:/ETH:volume': 4246576.84,
#   'bitstamp:/BTC:date': Timestamp('2018-05-15 06:00:00'),
#   'bitstamp:/BTC:unix': 1526364000.0,
#   'bitstamp:/BTC:open': 8733.86,
#   'bitstamp:/BTC:high': 8796.68,
#   'bitstamp:/BTC:low': 8707.28,
#   'bitstamp:/BTC:close': 8740.99,
#   'bitstamp:/BTC:volume': 559.93,
#   'bitstamp:/LTC:date': Timestamp('2018-05-15 06:00:00'),
#   'bitstamp:/LTC:unix': 1526364000,
#   'bitstamp:/LTC:open': 147.2,
#   'bitstamp:/LTC:high': 148.7,
#   'bitstamp:/LTC:low': 147.01,
#   'bitstamp:/LTC:close': 147.2,
#   'bitstamp:/LTC:volume': 1907.28,
#   'bitstamp:/LTC:volume_adi': -1478.424142011839,
#   'bitstamp:/LTC:volume_obv': 1907.28,
#   'bitstamp:/LTC:volume_cmf': nan,
#   'bitstamp:/LTC:volume_fi': nan,
#   'bitstamp:/LTC:volume_em': nan,
#   'bitstamp:/LTC:volume_sma_em': nan,
#   'bitstamp:/LTC:volume_vpt': nan,
#   'bitstamp:/LTC:volume_vwap': nan,
#   'bitstamp:/LTC:volume_mfi': nan,
#   'bitstamp:/LTC:volume_nvi': 1000.0,
#   'bitstamp:/LTC:volatility_bbm': nan,
#   'bitstamp:/LTC:volatility_bbh': nan,
#   'bitstamp:/LTC:volatility_bbl': nan,
#   'bitstamp:/LTC:volatility_bbw': nan,
#   'bitstamp:/LTC:volatility_bbp': nan,
#   'bitstamp:/LTC:volatility_bbhi': 0.0,
#   'bitstamp:/LTC:volatility_bbli': 0.0,
#   'bitstamp:/LTC:volatility_kcc': nan,
#   'bitstamp:/LTC:volatility_kch': 149.32666666666665,
#   'bitstamp:/LTC:volatility_kcl': 145.94666666666666,
#   'bitstamp:/LTC:volatility_kcw': nan,
#   'bitstamp:/LTC:volatility_kcp': 0.3708086785009858,
#   'bitstamp:/LTC:volatility_kchi': 0.0,
#   'bitstamp:/LTC:volatility_kcli': 0.0,
#   'bitstamp:/LTC:volatility_dcl': nan,
#   'bitstamp:/LTC:volatility_dch': nan,
#   'bitstamp:/LTC:volatility_dcm': nan,
#   'bitstamp:/LTC:volatility_dcw': nan,
#   'bitstamp:/LTC:volatility_dcp': nan,
#   'bitstamp:/LTC:volatility_atr': 0.0,
#   'bitstamp:/LTC:volatility_ui': nan,
#   'bitstamp:/LTC:trend_macd': nan,
#   'bitstamp:/LTC:trend_macd_signal': nan,
#   'bitstamp:/LTC:trend_macd_diff': nan,
#   'bitstamp:/LTC:trend_sma_fast': nan,
#   'bitstamp:/LTC:trend_sma_slow': nan,
#   'bitstamp:/LTC:trend_ema_fast': nan,
#   'bitstamp:/LTC:trend_ema_slow': nan,
#   'bitstamp:/LTC:trend_vortex_ind_pos': nan,
#   'bitstamp:/LTC:trend_vortex_ind_neg': nan,
#   'bitstamp:/LTC:trend_vortex_ind_diff': nan,
#   'bitstamp:/LTC:trend_trix': nan,
#   'bitstamp:/LTC:trend_mass_index': nan,
#   'bitstamp:/LTC:trend_dpo': nan,
#   'bitstamp:/LTC:trend_kst': nan,
#   'bitstamp:/LTC:trend_kst_sig': nan,
#   'bitstamp:/LTC:trend_kst_diff': nan,
#   'bitstamp:/LTC:trend_ichimoku_conv': nan,
#   'bitstamp:/LTC:trend_ichimoku_base': nan,
#   'bitstamp:/LTC:trend_ichimoku_a': nan,
#   'bitstamp:/LTC:trend_ichimoku_b': 147.855,
#   'bitstamp:/LTC:trend_stc': nan,
#   'bitstamp:/LTC:trend_adx': 0.0,
#   'bitstamp:/LTC:trend_adx_pos': 0.0,
#   'bitstamp:/LTC:trend_adx_neg': 0.0,
#   'bitstamp:/LTC:trend_cci': nan,
#   'bitstamp:/LTC:trend_visual_ichimoku_a': 89.93063732472385,
#   'bitstamp:/LTC:trend_visual_ichimoku_b': 89.92024916549335,
#   'bitstamp:/LTC:trend_aroon_up': nan,
#   'bitstamp:/LTC:trend_aroon_down': nan,
#   'bitstamp:/LTC:trend_aroon_ind': nan,
#   'bitstamp:/LTC:trend_psar_up': nan,
#   'bitstamp:/LTC:trend_psar_down': nan,
#   'bitstamp:/LTC:trend_psar_up_indicator': 0.0,
#   'bitstamp:/LTC:trend_psar_down_indicator': 0.0,
#   'bitstamp:/LTC:momentum_rsi': nan,
#   'bitstamp:/LTC:momentum_stoch_rsi': nan,
#   'bitstamp:/LTC:momentum_stoch_rsi_k': nan,
#   'bitstamp:/LTC:momentum_stoch_rsi_d': nan,
#   'bitstamp:/LTC:momentum_tsi': nan,
#   'bitstamp:/LTC:momentum_uo': nan,
#   'bitstamp:/LTC:momentum_stoch': nan,
#   'bitstamp:/LTC:momentum_stoch_signal': nan,
#   'bitstamp:/LTC:momentum_wr': nan,
#   'bitstamp:/LTC:momentum_ao': nan,
#   'bitstamp:/LTC:momentum_roc': nan,
#   'bitstamp:/LTC:momentum_ppo': nan,
#   'bitstamp:/LTC:momentum_ppo_signal': nan,
#   'bitstamp:/LTC:momentum_ppo_hist': nan,
#   'bitstamp:/LTC:momentum_pvo': nan,
#   'bitstamp:/LTC:momentum_pvo_signal': nan,
#   'bitstamp:/LTC:momentum_pvo_hist': nan,
#   'bitstamp:/LTC:momentum_kama': nan,
#   'bitstamp:/LTC:others_dr': nan,
#   'bitstamp:/LTC:others_dlr': nan,
#   'bitstamp:/LTC:others_cr': 0.0}}
